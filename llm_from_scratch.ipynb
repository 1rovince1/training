# %%
import torch
# Out:
# /home/rovince/miniconda3/envs/llm_from_scratch/lib/python3.11/site-packages/torch/_subclasses/functional_tensor.py:362: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
torch.tensor([[1., 2, 3], [5, 4, 2]])
# Out:
# tensor([[1., 2., 3.],
#         [5., 4., 2.]])

# %%
import torch.nn.functional as F

y = torch.tensor([1.])
x1 = torch.tensor([1.1])
w1 = torch.tensor([0.84])
b = torch.tensor([2.3])

z = x1 * w1 + b
a = torch.sigmoid(z)

loss = F.binary_cross_entropy(a, y)

# %%
loss
# Out:
# tensor(0.0390)

# %%
import torch.nn.functional as F
from torch.autograd import grad

y = torch.tensor([1.])
x1 = torch.tensor([1.1])
w1 = torch.tensor([0.84], requires_grad=True)
b = torch.tensor([2.3], requires_grad=True)

z = x1 * w1 + b
a = torch.sigmoid(z)

loss = F.binary_cross_entropy(a, y)

grad_L_w1 = grad(loss, w1, retain_graph=True)
grad_L_b = grad(loss, b, retain_graph=True)

# %%
print(grad_L_w1, grad_L_b)
# Out:
# (tensor([-0.0421]),) (tensor([-0.0383]),)

# %%
loss.backward()

# %%
print(w1.grad, b.grad)
# Out:
# tensor([-0.0421]) tensor([-0.0383])

# %%
class NeuralNetwork(torch.nn.Module):
    def __init__(self, input_units, output_units):
        super().__init__()

        self.layers = torch.nn.Sequential(
            torch.nn.Linear(input_units, 30),
            torch.nn.ReLU(),
            torch.nn.Linear(30, 20),
            torch.nn.ReLU(),
            torch.nn.Linear(20, output_units)
        )

    def forward(self, x):
        logits = self.layers(x)
        return logits

# %%
model = NeuralNetwork(50, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 model = NeuralNetwork(50, 3)
#
# Cell In[13], line 3, in NeuralNetwork.__init__(self, input_units, output_units)
#       2     def __init__(self, input_units, output_units):
# ----> 3         super.__init__()
#       4
#       5         self.layers = torch.nn.Sequential(
#       6             torch.nn.Linear(input_units, 30),
#
# TypeError: descriptor '__init__' of 'super' object needs an argument
